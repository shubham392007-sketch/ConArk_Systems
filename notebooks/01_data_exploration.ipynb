# %% [markdown]
# # 01. ConArk Systems – Construction Monitoring Data Exploration
# Exploratory Data Analysis (EDA) for 50,000 time-series construction site records.

# %%
import sys
sys.path.append('../src')
from conark.data.loader import DataLoader
from conark.data.leakage_detector import analyze_target_leakage

loader = DataLoader()
df = loader.load_raw_dataset()
print('Dataset shape:', df.shape)
df.head()

# %%
leakage_info = analyze_target_leakage(df)
print('Target Leakage Analysis:', leakage_info)
