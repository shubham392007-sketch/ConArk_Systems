# %% [markdown]
# # 02. Time-Series Feature Engineering
# Lag features, rolling windows, velocity, efficiency ratios, and timestamp extraction.

# %%
import sys
sys.path.append('../src')
from conark.data.loader import DataLoader
from conark.features.engineering import create_feature_pipeline

loader = DataLoader()
df_raw = loader.load_raw_dataset()
df_feat = create_feature_pipeline(df_raw)
print('Engineered feature matrix shape:', df_feat.shape)
df_feat.head()
